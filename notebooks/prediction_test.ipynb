# %%
import pandas as pd
import os
from application_logging.logger import App_Logger
from prediction_Validation_Insertion import pred_validation
from Prediction_Raw_Data_Validation.predictionDataValidation import Prediction_Data_validation
from DataTransformation_Prediction.DataTransformationPrediction import dataTransformPredict
from DataTypeValidation_Insertion_Prediction.DataTypeValidationPrediction import dBOperation
from predictFromModel import prediction

# %%
os.getcwd()
# Out:
# 'c:\\Users\\anjik\\Desktop\\iNeuron_FSDS\\ML_end_to_end_projects\\ML_wafer_circleci_Heroku'

# %%
os.chdir("c:\\Users\\anjik\\Desktop\\iNeuron_FSDS\\ML_end_to_end_projects\\ML_wafer_circleci_Heroku")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\anjik\\Desktop\\iNeuron_FSDS\\ML_end_to_end_projects\\ML_wafer_circleci_Heroku'

# %% [markdown]
# ## Evaluate pred_validation class

# %% [markdown]
# ### check Prediction_Data_validation class

# %%
# required attributes to create train_validation class object
Batch_Directory = 'Prediction_Batch_files'
schema_path = 'schema_prediction.json'
logger = App_Logger() 
raw_data = Prediction_Data_validation(path= Batch_Directory)
raw_data

# %%
dic = raw_data.valuesFromSchema()
dic
# Out:
# (8,
#  6,
#  {'Wafer': 'varchar',
#   'Sensor - 1': ' float',
#   'Sensor - 2': ' float',
#   'Sensor - 3': ' float',
#   'Sensor - 4': ' float',
#   'Sensor - 5': ' float',
#   'Sensor - 6': ' float',
#   'Sensor - 7': ' float',
#   'Sensor - 8': ' float',
#   'Sensor - 9': ' float',
#   'Sensor - 10': ' float',
#   'Sensor - 11': ' float',
#   'Sensor - 12': ' float',
#   'Sensor - 13': ' float',
#   'Sensor - 14': ' float',
#   'Sensor - 15': ' float',
#   'Sensor - 16': ' float',
#   'Sensor - 17': ' float',
#   'Sensor - 18': ' float',
#   'Sensor - 19': ' float',
#   'Sensor - 20': ' float',
#   'Sensor - 21': ' float',
#   'Sensor - 22': ' float',
#   'Sensor - 23': ' float',
#   'Sensor - 24': ' float',
#   'Sensor - 25': ' float',
#   'Sensor - 26': ' float',
#   'Sensor - 27': ' float',
#   'Sensor - 28': ' float',
#   'Sensor - 29': ' float',
#   'Sensor - 30': ' float',
#   'Sensor - 31': ' float',
#   'Sensor - 32': ' float',
#   'Sensor - 33': ' float',
# ...

# %%
raw_data.manualRegexCreation()
# Out:
# "['wafer']+['\\_'']+[\\d_]+[\\d]+\\.csv"

# %%
raw_data.createDirectoryForGoodBadRawData()

# %%
raw_data.deleteExistingGoodDataTrainingFolder()

# %%
raw_data.deleteExistingBadDataTrainingFolder()

# %%
raw_data.moveBadFilesToArchiveBad()

# %%
regex = "['wafer']+['\\_'']+[\\d_]+[\\d]+\\.csv"
LengthOfDateStampInFile = dic[0]
LengthOfTimeStampInFile = dic[1]
raw_data.validationFileNameRaw(regex,LengthOfDateStampInFile,LengthOfTimeStampInFile)

# %%
NumberofColumns = dic[-1]
raw_data.validateColumnLength(NumberofColumns)

# %%
raw_data.deletePredictionFile()

# %%
raw_data.validateMissingValuesInWholeColumn()

# %% [markdown]
# ## check dataTransformPredict class

# %%
goodDataPath = "Prediction_Raw_Files_Validated/Good_Raw"
logger = App_Logger()
dataTransform = dataTransformPredict()
dataTransform

# %%
dataTransform.replaceMissingWithNull()

# %% [markdown]
# ## check dBOperation class

# %%
path = 'Prediction_Database/'
badFilePath = "Prediction_Raw_Files_Validated/Bad_Raw"
goodFilePath = "Prediction_Raw_Files_Validated/Good_Raw"
logger = App_Logger()
dBOperation = dBOperation()
dBOperation

# %%
dBOperation.dataBaseConnection('Prediction')

# %%
column_names = dic[2]
column_names
# Out:
# {'Wafer': 'varchar',
#  'Sensor - 1': ' float',
#  'Sensor - 2': ' float',
#  'Sensor - 3': ' float',
#  'Sensor - 4': ' float',
#  'Sensor - 5': ' float',
#  'Sensor - 6': ' float',
#  'Sensor - 7': ' float',
#  'Sensor - 8': ' float',
#  'Sensor - 9': ' float',
#  'Sensor - 10': ' float',
#  'Sensor - 11': ' float',
#  'Sensor - 12': ' float',
#  'Sensor - 13': ' float',
#  'Sensor - 14': ' float',
#  'Sensor - 15': ' float',
#  'Sensor - 16': ' float',
#  'Sensor - 17': ' float',
#  'Sensor - 18': ' float',
#  'Sensor - 19': ' float',
#  'Sensor - 20': ' float',
#  'Sensor - 21': ' float',
#  'Sensor - 22': ' float',
#  'Sensor - 23': ' float',
#  'Sensor - 24': ' float',
#  'Sensor - 25': ' float',
#  'Sensor - 26': ' float',
#  'Sensor - 27': ' float',
#  'Sensor - 28': ' float',
#  'Sensor - 29': ' float',
#  'Sensor - 30': ' float',
#  'Sensor - 31': ' float',
#  'Sensor - 32': ' float',
#  'Sensor - 33': ' float',
#  'Sensor - 34': ' float',
#  'Sensor - 35': ' float',
# ...

# %%
column_names = dic[2]

dBOperation.createTableDb('Prediction',column_names)

# %%
dBOperation.insertIntoTableGoodData('Prediction')

# %%
dBOperation.selectingDatafromtableintocsv('Prediction')

# %%
file_object = open("Prediction_Logs/Prediction_Log.txt", 'a+')
file_object
# Out:
# <_io.TextIOWrapper name='Prediction_Logs/Prediction_Log.txt' mode='a+' encoding='UTF-8'>

# %%
pred_val = pred_validation(path= Batch_Directory)
pred_val

# %%
pred_val.prediction_validation()

# %% [markdown]
# ## check prediction class

# %%
file_object = open("Prediction_Logs/Prediction_Log.txt", 'a+')
log_writer = App_Logger()
pred_data_val = Prediction_Data_validation(path= Batch_Directory)
pred = prediction(path= Batch_Directory)
pred

# %%
pred.predictionFromModel()
# Out:
# ('Prediction_Output_File/Predictions.csv',
#  '[{"Wafer":1208.0,"Prediction":-1},{"Wafer":1209.0,"Prediction":-1},{"Wafer":1213.0,"Prediction":-1},{"Wafer":1214.0,"Prediction":-1},{"Wafer":1219.0,"Prediction":-1}]')
